# %%
import pandas as pd
import numpy as np
# !pip install word2number
from word2number import w2n
import warnings 
warnings.filterwarnings("ignore")
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
flat=pd.read_csv('hiring.csv')

# %%
print(flat.to_string())
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
print(flat.columns)
# Out:
# Index(['experience', 'test_score(out of 10)', 'interview_score(out of 10)',
#        'salary($)'],
#       dtype='object')

# %%
mean_value = flat['test_score(out of 10)'].mean()
flat['test_score(out of 10)'].fillna(value=mean_value, inplace=True)

# %%
flat['experience']=flat['experience'].fillna("zero")

# %%
flat
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero               8.000000                           9      50000
# 1       zero               8.000000                           6      45000
# 2       five               6.000000                           7      60000
# 3        two              10.000000                          10      65000
# 4      seven               9.000000                           6      70000
# 5      three               7.000000                          10      62000
# 6        ten               7.857143                           7      72000
# 7     eleven               7.000000                           8      80000

# %%
flat['experience']=flat['experience'].apply(w2n.word_to_num)

# %%
flat
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0               8.000000                           9      50000
# 1           0               8.000000                           6      45000
# 2           5               6.000000                           7      60000
# 3           2              10.000000                          10      65000
# 4           7               9.000000                           6      70000
# 5           3               7.000000                          10      62000
# 6          10               7.857143                           7      72000
# 7          11               7.000000                           8      80000

# %%
x=flat.drop(columns=['salary($)'])
y=flat['salary($)']

# %%
print(x.to_string())
print(y.to_string())
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0           0               8.000000                           9
# 1           0               8.000000                           6
# 2           5               6.000000                           7
# 3           2              10.000000                          10
# 4           7               9.000000                           6
# 5           3               7.000000                          10
# 6          10               7.857143                           7
# 7          11               7.000000                           8
# 0    50000
# 1    45000
# 2    60000
# 3    65000
# 4    70000
# 5    62000
# 6    72000
# 7    80000

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
ans=model.predict([[2,9,6],[12,10,10]])
print(ans)
# Out:
# [53290.89255945 92268.07227784]
